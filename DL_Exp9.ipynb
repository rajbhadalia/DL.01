zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX
# Resolving docs.google.com (docs.google.com)... 172.217.13.78, 2607:f8b0:4004:807::200e
# Connecting to docs.google.com (docs.google.com)|172.217.13.78|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/t25lmq7fgcgeqbs080a31e3tcktne3rg/1617206100000/17242455652310080862/*/1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2021-03-31 15:55:55--  https://doc-0c-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/t25lmq7fgcgeqbs080a31e3tcktne3rg/1617206100000/17242455652310080862/*/1zJxB1YzBYuImaHBSxWGN-ZXPDRYN_CTX?e=download
# Resolving doc-0c-7s-docs.googleusercontent.com (doc-0c-7s-docs.googleusercontent.com)... 172.217.15.97, 2607:f8b0:4004:811::2001
# Connecting to doc-0c-7s-docs.googleusercontent.com (doc-0c-7s-docs.googleusercontent.com)|172.217.15.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘valid.p’
#
# valid.p                 [   <=>              ]  12.95M  19.2MB/s    in 0.7s
#
# 2021-03-31 15:55:56 (19.2 MB/s) - ‘valid.p’ saved [13578712]
#
# --2021-03-31 15:55:56--  https://docs.google.com/uc?export=download&id=1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0
# Resolving docs.google.com (docs.google.com)... 172.217.13.78, 2607:f8b0:4004:808::200e
# Connecting to docs.google.com (docs.google.com)|172.217.13.78|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ns2gjfl9727m2jfmfh5fiufmum1vuenn/1617206100000/17242455652310080862/*/1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2021-03-31 15:55:58--  https://doc-0g-7s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ns2gjfl9727m2jfmfh5fiufmum1vuenn/1617206100000/17242455652310080862/*/1jZhZpEZkYFaaPPAwfd1cB8e-FK0aoeC0?e=download
# Resolving doc-0g-7s-docs.googleusercontent.com (doc-0g-7s-docs.googleusercontent.com)... 172.217.15.97, 2607:f8b0:4004:811::2001
# Connecting to doc-0g-7s-docs.googleusercontent.com (doc-0g-7s-docs.googleusercontent.com)|172.217.15.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/x-pascal]
# Saving to: ‘test.p’
#
# test.p                  [    <=>             ]  37.09M  38.2MB/s    in 1.0s
#
# 2021-03-31 15:55:59 (38.2 MB/s) - ‘test.p’ saved [38888118]

# %%
with open("/content/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("/content/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("/content/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %% [markdown]
# # TASK #3: PERFROM IMAGES VISUALIZATION

# %%
i = np.random.randint(1, len(X_train))
plt.imshow(X_train[i])
y_train[i]
# Out:
# 1

# %%
# Let's view more images in a grid format
# Define the dimensions of the plot grid 
W_grid = 5
L_grid = 5

# fig, axes = plt.subplots(L_grid, W_grid)
# subplot return the figure object and axes object
# we can use the axes object to plot specific figures at various locations

fig, axes = plt.subplots(L_grid, W_grid, figsize = (10,10))

axes = axes.ravel() # flaten the 15 x 15 matrix into 225 array

n_training = len(X_train) # get the length of the training dataset

# Select a random number from 0 to n_training
for i in np.arange(0, W_grid * L_grid): # create evenly spaces variables 

    # Select a random number
    index = np.random.randint(0, n_training)
    # read and display an image with the selected index    
    axes[i].imshow( X_train[index])
    axes[i].set_title(y_train[index], fontsize = 15)
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.4)

# %% [markdown]
# # TASK #4: CONVERT IMAGES TO GRAYSCALE AND PERFORM NORMALIZATION

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %% [markdown]
# #Since its an RGB image, so it means that you have add r with g with b and then divide it by 3 to get your desired grayscale image. Its done in this way. If you have an color image like the image shown above and you want to convert it into grayscale using average method.

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis = 3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_test_gray.shape
# Out:
# (12630, 32, 32, 1)

# %%
X_validation_gray.shape
# Out:
# (4410, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128
X_validation_gray_norm = (X_validation_gray - 128)/128

# %%
X_train_gray_norm
# Out:
# array([[[[-0.77604167],
#          [-0.77083333],
#          [-0.73177083],
#          ...,
#          [-0.69791667],
#          [-0.6796875 ],
#          [-0.734375  ]],
#
#         [[-0.7890625 ],
#          [-0.76041667],
#          [-0.71614583],
#          ...,
#          [-0.70572917],
#          [-0.6953125 ],
#          [-0.71875   ]],
#
#         [[-0.78125   ],
#          [-0.75520833],
#          [-0.72395833],
#          ...,
#          [-0.70572917],
#          [-0.70572917],
#          [-0.71875   ]],
#
#         ...,
#
#         [[-0.70833333],
#          [-0.69791667],
#          [-0.70052083],
#          ...,
#          [-0.7265625 ],
#          [-0.72395833],
#          [-0.71875   ]],
#
#         [[-0.72916667],
#          [-0.72395833],
#          [-0.70833333],
#          ...,
#          [-0.72135417],
#          [-0.71614583],
#          [-0.71354167]],
#
#         [[-0.74479167],
#          [-0.7421875 ],
#          [-0.72135417],
#          ...,
#          [-0.73958333],
#          [-0.72395833],
#          [-0.72916667]]],
#
#
#        [[[-0.84375   ],
#          [-0.84114583],
#          [-0.84635417],
#          ...,
#          [-0.85416667],
#          [-0.85416667],
#          [-0.8671875 ]],
#
#         [[-0.84114583],
#          [-0.84895833],
#          [-0.8515625 ],
#          ...,
#          [-0.85677083],
#          [-0.84895833],
#          [-0.86458333]],
#
#         [[-0.84895833],
#          [-0.84114583],
#          [-0.84895833],
#          ...,
#          [-0.859375  ],
#          [-0.859375  ],
#          [-0.859375  ]],
#
#         ...,
#
#         [[-0.80729167],
#          [-0.80989583],
#          [-0.81510417],
#          ...,
#          [-0.83072917],
#          [-0.83072917],
#          [-0.82291667]],
#
#         [[-0.80208333],
#          [-0.8203125 ],
#          [-0.81510417],
#          ...,
#          [-0.85416667],
#          [-0.84895833],
#          [-0.85416667]],
#
#         [[-0.84375   ],
#          [-0.84375   ],
#          [-0.83854167],
#          ...,
#          [-0.875     ],
#          [-0.8671875 ],
#          [-0.8671875 ]]],
#
#
#        [[[-0.54427083],
#          [-0.5625    ],
#          [-0.56770833],
#          ...,
#          [-0.43229167],
#          [-0.44791667],
#          [-0.47916667]],
#
#         [[-0.5546875 ],
#          [-0.58333333],
#          [-0.58072917],
#          ...,
#          [-0.46354167],
#          [-0.47916667],
#          [-0.46354167]],
#
#         [[-0.57291667],
#          [-0.59114583],
#          [-0.58854167],
#          ...,
#          [-0.46354167],
#          [-0.46875   ],
#          [-0.48958333]],
#
#         ...,
#
#         [[-0.671875  ],
#          [-0.68489583],
#          [-0.68489583],
#          ...,
#          [-0.60416667],
#          [-0.61979167],
#          [-0.61979167]],
#
#         [[-0.6796875 ],
#          [-0.68489583],
#          [-0.67447917],
#          ...,
#          [-0.62760417],
#          [-0.63020833],
#          [-0.62239583]],
#
#         [[-0.6796875 ],
#          [-0.67708333],
#          [-0.6640625 ],
#          ...,
#          [-0.63020833],
#          [-0.63020833],
#          [-0.63541667]]],
#
#
#        ...,
#
#
#        [[[ 0.95833333],
#          [ 0.94270833],
#          [ 0.9453125 ],
#          ...,
#          [ 0.296875  ],
#          [-0.42708333],
#          [-0.57291667]],
#
#         [[ 0.90625   ],
#          [ 0.85416667],
#          [ 0.83854167],
#          ...,
#          [ 0.33072917],
#          [-0.3828125 ],
#          [-0.52864583]],
#
#         [[ 0.859375  ],
#          [ 0.828125  ],
#          [ 0.7890625 ],
#          ...,
#          [ 0.34895833],
#          [-0.35677083],
#          [-0.50520833]],
#
#         ...,
#
#         [[ 0.625     ],
#          [ 0.56770833],
#          [ 0.5546875 ],
#          ...,
#          [-0.46875   ],
#          [-0.50520833],
#          [-0.5       ]],
#
#         [[ 0.625     ],
#          [ 0.58854167],
#          [ 0.59114583],
#          ...,
#          [-0.48177083],
#          [-0.51302083],
#          [-0.4921875 ]],
#
#         [[ 0.63541667],
#          [ 0.59375   ],
#          [ 0.59895833],
#          ...,
#          [-0.47395833],
#          [-0.5078125 ],
#          [-0.49739583]]],
#
#
#        [[[-0.66666667],
#          [-0.72395833],
#          [-0.82291667],
#          ...,
#          [-0.41666667],
#          [-0.1875    ],
#          [-0.00520833]],
#
#         [[-0.77083333],
#          [-0.79947917],
#          [-0.80989583],
#          ...,
#          [-0.21875   ],
#          [-0.08854167],
#          [-0.23958333]],
#
#         [[-0.72135417],
#          [-0.70052083],
#          [-0.734375  ],
#          ...,
#          [-0.421875  ],
#          [-0.34375   ],
#          [-0.1328125 ]],
#
#         ...,
#
#         [[-0.796875  ],
#          [-0.796875  ],
#          [-0.765625  ],
#          ...,
#          [-0.64322917],
#          [-0.61197917],
#          [-0.70052083]],
#
#         [[-0.7734375 ],
#          [-0.76822917],
#          [-0.73697917],
#          ...,
#          [-0.64583333],
#          [-0.63541667],
#          [-0.671875  ]],
#
#         [[-0.70052083],
#          [-0.71875   ],
#          [-0.73177083],
#          ...,
#          [-0.58854167],
#          [-0.64322917],
#          [-0.6875    ]]],
#
#
#        [[[ 0.93229167],
#          [ 0.94010417],
#          [ 0.94791667],
#          ...,
#          [ 0.90625   ],
#          [ 0.890625  ],
#          [ 0.90364583]],
#
#         [[ 0.9375    ],
#          [ 0.94010417],
#          [ 0.94270833],
#          ...,
#          [ 0.89583333],
#          [ 0.8984375 ],
#          [ 0.89322917]],
#
#         [[ 0.93489583],
#          [ 0.94010417],
#          [ 0.93229167],
#          ...,
#          [ 0.89583333],
#          [ 0.90364583],
#          [ 0.88541667]],
#
#         ...,
#
#         [[-0.25520833],
#          [-0.30208333],
#          [-0.23958333],
#          ...,
#          [-0.74479167],
#          [-0.77864583],
#          [-0.8046875 ]],
#
#         [[-0.171875  ],
#          [-0.3046875 ],
#          [-0.27604167],
#          ...,
#          [-0.73958333],
#          [-0.7890625 ],
#          [-0.8046875 ]],
#
#         [[-0.07552083],
#          [-0.20572917],
#          [-0.2265625 ],
#          ...,
#          [-0.7421875 ],
#          [-0.78645833],
#          [-0.78125   ]]]])

# %%
i = random.randint(1, len(X_train_gray))
plt.imshow(X_train_gray[i].squeeze(), cmap = 'gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap = 'gray')

# %% [markdown]
# # TASK #6: BUILD DEEP CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras import datasets, layers, models

CNN = models.Sequential()

CNN.add(layers.Conv2D(6, (5,5), activation = 'relu', input_shape = (32,32,1)))
CNN.add(layers.AveragePooling2D())

#CNN.add(layers.Dropout(0.2))

CNN.add(layers.Conv2D(16, (5,5), activation = 'relu'))
CNN.add(layers.AveragePooling2D())

CNN.add(layers.Flatten())

CNN.add(layers.Dense(120, activation = 'relu'))

CNN.add(layers.Dense(84, activation = 'relu'))

CNN.add(layers.Dense(43, activation = 'softmax'))
CNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # TASK #7: COMPILE AND TRAIN DEEP CNN MODEL

# %%
CNN.compile(optimizer = 'Adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = CNN.fit(X_train_gray_norm,
                 y_train, 
                 batch_size = 500,
                 epochs = 5,
                 verbose = 1,
                 validation_data = (X_validation_gray_norm, y_validation))
# Out:
# Epoch 1/5
# 70/70 [==============================] - 33s 14ms/step - loss: 3.4794 - accuracy: 0.1017 - val_loss: 2.5819 - val_accuracy: 0.2952
# Epoch 2/5
# 70/70 [==============================] - 0s 6ms/step - loss: 1.9580 - accuracy: 0.4611 - val_loss: 1.3797 - val_accuracy: 0.5773
# Epoch 3/5
# 70/70 [==============================] - 0s 6ms/step - loss: 1.0110 - accuracy: 0.7161 - val_loss: 1.0068 - val_accuracy: 0.7091
# Epoch 4/5
# 70/70 [==============================] - 0s 6ms/step - loss: 0.7403 - accuracy: 0.7948 - val_loss: 0.8072 - val_accuracy: 0.7707
# Epoch 5/5
# 70/70 [==============================] - 0s 6ms/step - loss: 0.5829 - accuracy: 0.8466 - val_loss: 0.7130 - val_accuracy: 0.7982

# %% [markdown]
# # TASK #8: ASSESS TRAINED CNN MODEL PERFORMANCE

# %%
score = CNN.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 1s 2ms/step - loss: 0.9341 - accuracy: 0.7817
# Test Accuracy: 0.7817102074623108

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

# %%
predicted_classes = CNN.predict_classes(X_test_gray_norm)
y_true = y_test
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (25, 25))
sns.heatmap(cm, annot = True)

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)
