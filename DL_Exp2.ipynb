# %% [markdown]
# <a href="https://colab.research.google.com/github/rajbhadalia/DL.01/blob/exp1/DL_Exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import time
from matplotlib import pyplot as plt
from PIL import Image
# %matplotlib inline
from ipywidgets import interact
import tensorflow as tf

# %%
from keras.datasets import mnist

# %%
(X_train,Y_train),(X_test,Y_test)=mnist.load_data()
print("X_train_shape"+str(X_train.shape))
print("Y_train_shape"+str(Y_train.shape))
print("X_test_shape"+str(X_test.shape))
print("Y_test_shape"+str(Y_test.shape))
# Out:
# X_train_shape(60000, 28, 28)
# Y_train_shape(60000,)
# X_test_shape(10000, 28, 28)
# Y_test_shape(10000,)

# %% [markdown]
# ## Defining seed

# %%
import random as rn

# %%
np.random.seed(42)
rn.seed(42)

# %% [markdown]
# ## Normalizing and reshaping images

# %%
X_train=X_train.reshape((60000,28*28))
X_test=X_test.reshape((10000,28*28))

print(X_train.shape)
print(X_test.shape)

X_train=X_train.astype('float32')/255
X_test=X_test.astype('float32')/255
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# ## Ploting the images

# %%
fig = plt.figure(figsize=(8, 6))
for i in range(20):
    ax = fig.add_subplot(4, 5, i+1, xticks=[], yticks=[])
    ax.imshow(X_train[i].reshape(28,28), cmap=plt.cm.bone)

# %% [markdown]
# ## Building ANN

# %%
from keras import models
from keras import layers
from keras import optimizers
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
Y_train_cat = tf.keras.utils.to_categorical(Y_train)
Y_test_cat = tf.keras.utils.to_categorical(Y_test)

# %%
from keras import models
from keras import layers

nn = models.Sequential()
nn.add(layers.Dense(512, activation="tanh",input_shape=(28*28, )))
nn.add(layers.Dense(256, activation="sigmoid"))
nn.add(layers.Dense(64, activation="tanh"))
nn.add(layers.Dense(32, activation="relu"))
nn.add(layers.Dense(10, activation="softmax"))
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# =================================================================
# Total params: 552,106
# Trainable params: 552,106
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn.compile(optimizer="rmsprop",
           loss='categorical_crossentropy',
           metrics = ['accuracy'])

# %% [markdown]
# ## Using callbacks

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100)
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# %% [markdown]
# ## Running the model

# %%
history = nn.fit(X_train,Y_train_cat, epochs=50, batch_size = 100, validation_split=0.05, verbose=2, callbacks=[es, mc])
# Out:
# Epoch 1/50
# 570/570 - 4s - loss: 0.3650 - accuracy: 0.8926 - val_loss: 0.1271 - val_accuracy: 0.9627
#
# Epoch 00001: val_accuracy improved from -inf to 0.96267, saving model to best_model.h5
# Epoch 2/50
# 570/570 - 2s - loss: 0.1491 - accuracy: 0.9549 - val_loss: 0.0923 - val_accuracy: 0.9740
#
# Epoch 00002: val_accuracy improved from 0.96267 to 0.97400, saving model to best_model.h5
# Epoch 3/50
# 570/570 - 2s - loss: 0.1003 - accuracy: 0.9694 - val_loss: 0.0800 - val_accuracy: 0.9757
#
# Epoch 00003: val_accuracy improved from 0.97400 to 0.97567, saving model to best_model.h5
# Epoch 4/50
# 570/570 - 2s - loss: 0.0738 - accuracy: 0.9767 - val_loss: 0.0747 - val_accuracy: 0.9800
#
# Epoch 00004: val_accuracy improved from 0.97567 to 0.98000, saving model to best_model.h5
# Epoch 5/50
# 570/570 - 2s - loss: 0.0575 - accuracy: 0.9814 - val_loss: 0.0735 - val_accuracy: 0.9783
#
# Epoch 00005: val_accuracy did not improve from 0.98000
# Epoch 6/50
# 570/570 - 2s - loss: 0.0440 - accuracy: 0.9860 - val_loss: 0.0680 - val_accuracy: 0.9837
#
# Epoch 00006: val_accuracy improved from 0.98000 to 0.98367, saving model to best_model.h5
# Epoch 7/50
# 570/570 - 2s - loss: 0.0345 - accuracy: 0.9893 - val_loss: 0.0748 - val_accuracy: 0.9807
#
# Epoch 00007: val_accuracy did not improve from 0.98367
# Epoch 8/50
# 570/570 - 2s - loss: 0.0279 - accuracy: 0.9906 - val_loss: 0.0679 - val_accuracy: 0.9833
#
# Epoch 00008: val_accuracy did not improve from 0.98367
# Epoch 9/50
# 570/570 - 2s - loss: 0.0221 - accuracy: 0.9930 - val_loss: 0.0762 - val_accuracy: 0.9800
#
# Epoch 00009: val_accuracy did not improve from 0.98367
# Epoch 10/50
# 570/570 - 2s - loss: 0.0170 - accuracy: 0.9944 - val_loss: 0.0877 - val_accuracy: 0.9817
#
# Epoch 00010: val_accuracy did not improve from 0.98367
# Epoch 11/50
# 570/570 - 2s - loss: 0.0146 - accuracy: 0.9949 - val_loss: 0.0922 - val_accuracy: 0.9823
#
# Epoch 00011: val_accuracy did not improve from 0.98367
# Epoch 12/50
# 570/570 - 2s - loss: 0.0119 - accuracy: 0.9964 - val_loss: 0.0983 - val_accuracy: 0.9830
#
# Epoch 00012: val_accuracy did not improve from 0.98367
# Epoch 13/50
# 570/570 - 2s - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.0907 - val_accuracy: 0.9840
#
# Epoch 00013: val_accuracy improved from 0.98367 to 0.98400, saving model to best_model.h5
# Epoch 14/50
# 570/570 - 2s - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.1022 - val_accuracy: 0.9820
#
# Epoch 00014: val_accuracy did not improve from 0.98400
# Epoch 15/50
# 570/570 - 2s - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.1019 - val_accuracy: 0.9817
#
# Epoch 00015: val_accuracy did not improve from 0.98400
# Epoch 16/50
# 570/570 - 2s - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.1015 - val_accuracy: 0.9860
#
# Epoch 00016: val_accuracy improved from 0.98400 to 0.98600, saving model to best_model.h5
# Epoch 17/50
# 570/570 - 2s - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.1133 - val_accuracy: 0.9833
#
# Epoch 00017: val_accuracy did not improve from 0.98600
# Epoch 18/50
# 570/570 - 2s - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.1174 - val_accuracy: 0.9817
#
# Epoch 00018: val_accuracy did not improve from 0.98600
# Epoch 19/50
# 570/570 - 2s - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.1332 - val_accuracy: 0.9810
#
# Epoch 00019: val_accuracy did not improve from 0.98600
# Epoch 20/50
# 570/570 - 2s - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.1157 - val_accuracy: 0.9843
#
# Epoch 00020: val_accuracy did not improve from 0.98600
# Epoch 21/50
# 570/570 - 2s - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.1218 - val_accuracy: 0.9843
#
# Epoch 00021: val_accuracy did not improve from 0.98600
# Epoch 22/50
# 570/570 - 2s - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.1346 - val_accuracy: 0.9797
#
# Epoch 00022: val_accuracy did not improve from 0.98600
# Epoch 23/50
# 570/570 - 2s - loss: 0.0044 - accuracy: 0.9988 - val_loss: 0.1150 - val_accuracy: 0.9837
#
# Epoch 00023: val_accuracy did not improve from 0.98600
# Epoch 24/50
# 570/570 - 2s - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.1133 - val_accuracy: 0.9860
#
# Epoch 00024: val_accuracy did not improve from 0.98600
# Epoch 25/50
# 570/570 - 2s - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.1323 - val_accuracy: 0.9843
#
# Epoch 00025: val_accuracy did not improve from 0.98600
# Epoch 26/50
# 570/570 - 2s - loss: 0.0023 - accuracy: 0.9993 - val_loss: 0.1464 - val_accuracy: 0.9830
#
# Epoch 00026: val_accuracy did not improve from 0.98600
# Epoch 27/50
# 570/570 - 2s - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.1378 - val_accuracy: 0.9830
#
# Epoch 00027: val_accuracy did not improve from 0.98600
# Epoch 28/50
# 570/570 - 2s - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.1530 - val_accuracy: 0.9800
#
# Epoch 00028: val_accuracy did not improve from 0.98600
# Epoch 29/50
# 570/570 - 2s - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.1383 - val_accuracy: 0.9860
#
# Epoch 00029: val_accuracy did not improve from 0.98600
# Epoch 30/50
# 570/570 - 2s - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.1399 - val_accuracy: 0.9837
#
# Epoch 00030: val_accuracy did not improve from 0.98600
# Epoch 31/50
# 570/570 - 2s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1589 - val_accuracy: 0.9830
#
# Epoch 00031: val_accuracy did not improve from 0.98600
# Epoch 32/50
# 570/570 - 2s - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.1557 - val_accuracy: 0.9827
#
# Epoch 00032: val_accuracy did not improve from 0.98600
# Epoch 33/50
# 570/570 - 2s - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.1781 - val_accuracy: 0.9813
#
# Epoch 00033: val_accuracy did not improve from 0.98600
# Epoch 34/50
# 570/570 - 2s - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.1680 - val_accuracy: 0.9837
#
# Epoch 00034: val_accuracy did not improve from 0.98600
# Epoch 35/50
# 570/570 - 2s - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.2118 - val_accuracy: 0.9787
#
# Epoch 00035: val_accuracy did not improve from 0.98600
# Epoch 36/50
# 570/570 - 2s - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.1591 - val_accuracy: 0.9823
#
# Epoch 00036: val_accuracy did not improve from 0.98600
# Epoch 37/50
# 570/570 - 2s - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1766 - val_accuracy: 0.9833
#
# Epoch 00037: val_accuracy did not improve from 0.98600
# Epoch 38/50
# 570/570 - 2s - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.1555 - val_accuracy: 0.9850
#
# Epoch 00038: val_accuracy did not improve from 0.98600
# Epoch 39/50
# 570/570 - 2s - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1781 - val_accuracy: 0.9840
#
# Epoch 00039: val_accuracy did not improve from 0.98600
# Epoch 40/50
# 570/570 - 2s - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.1845 - val_accuracy: 0.9813
#
# Epoch 00040: val_accuracy did not improve from 0.98600
# Epoch 41/50
# 570/570 - 2s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.2098 - val_accuracy: 0.9830
#
# Epoch 00041: val_accuracy did not improve from 0.98600
# Epoch 42/50
# 570/570 - 2s - loss: 9.7767e-04 - accuracy: 0.9997 - val_loss: 0.2113 - val_accuracy: 0.9817
#
# Epoch 00042: val_accuracy did not improve from 0.98600
# Epoch 43/50
# 570/570 - 2s - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.2070 - val_accuracy: 0.9813
#
# Epoch 00043: val_accuracy did not improve from 0.98600
# Epoch 44/50
# 570/570 - 2s - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.2553 - val_accuracy: 0.9813
#
# Epoch 00044: val_accuracy did not improve from 0.98600
# Epoch 45/50
# 570/570 - 2s - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.2237 - val_accuracy: 0.9807
#
# Epoch 00045: val_accuracy did not improve from 0.98600
# Epoch 46/50
# 570/570 - 2s - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.2316 - val_accuracy: 0.9840
#
# Epoch 00046: val_accuracy did not improve from 0.98600
# Epoch 47/50
# 570/570 - 2s - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.2249 - val_accuracy: 0.9817
#
# Epoch 00047: val_accuracy did not improve from 0.98600
# Epoch 48/50
# 570/570 - 2s - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.1883 - val_accuracy: 0.9843
#
# Epoch 00048: val_accuracy did not improve from 0.98600
# Epoch 49/50
# 570/570 - 2s - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1942 - val_accuracy: 0.9860
#
# Epoch 00049: val_accuracy did not improve from 0.98600
# Epoch 50/50
# 570/570 - 2s - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.2019 - val_accuracy: 0.9833
#
# Epoch 00050: val_accuracy did not improve from 0.98600

# %%
test_loss,test_acc=nn.evaluate(X_test,Y_test_cat)
print(test_loss)
print(test_acc)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2032 - accuracy: 0.9810
# 0.20319396257400513
# 0.9810000061988831

# %% [markdown]
# ## Confusion matrix

# %%
predictions = nn.predict_classes(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
predictions
# Out:
# array([7, 2, 1, ..., 4, 5, 6])

# %%
predictions = to_categorical(predictions,10)

# %%
a = np.argmax(predictions ,axis=1)

# %%
b = np.argmax(Y_test_cat,axis=1)

# %%
from sklearn.metrics import confusion_matrix
from numpy import argmax

# %%
cm = confusion_matrix(a,b)
cm
# Out:
# array([[ 968,    0,    3,    0,    0,    2,    3,    2,    4,    1],
#        [   0, 1127,    2,    0,    1,    0,    2,    1,    0,    2],
#        [   0,    2, 1014,    2,    4,    0,    3,    7,    4,    0],
#        [   1,    0,    3,  987,    1,    9,    1,    0,    4,    4],
#        [   1,    0,    3,    0,  957,    1,    1,    1,    3,    7],
#        [   1,    1,    0,    2,    0,  871,    2,    0,    3,    4],
#        [   4,    1,    1,    0,    6,    4,  944,    0,    1,    1],
#        [   1,    2,    5,    8,    2,    0,    0, 1007,    3,    3],
#        [   3,    2,    1,    5,    0,    3,    2,    2,  949,    1],
#        [   1,    0,    0,    6,   11,    2,    0,    8,    3,  986]])

# %%
accuracy = sum(cm[i][i] for i in range(10)) / Y_test_cat.shape[0]
print("accuracy = " + str(accuracy))
# Out:
# accuracy = 0.981

# %% [markdown]
# ## Plots

# %%
plt.figure(figsize = (10,7))
plt.plot(history.history['accuracy'], color = 'blue')
plt.plot(history.history['val_accuracy'], color = 'red')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.figure(figsize = (10,7))
plt.plot(history.history['loss'], color= 'blue')
plt.plot(history.history['val_loss'], color = 'red')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Precision and recall

# %%
from sklearn.metrics import precision_score, recall_score
print('precision score - ',precision_score(Y_test_cat, predictions, average="macro"))
print('recall score - ', recall_score(Y_test_cat, predictions, average="macro"))
# Out:
# precision score -  0.9809425354655079
# recall score -  0.9807987665047072

# %% [markdown]
# ## Saving and Loading model

# %%
nn.save('best_model.h5')

# %%
from tensorflow import keras
model = keras.models.load_model('best_model.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                330
# =================================================================
# Total params: 552,106
# Trainable params: 552,106
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Deployement on Flask

# %%
# !pip install flask gevent requests pillow
# Out:
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (1.1.2)
# Requirement already satisfied: gevent in /usr/local/lib/python3.7/dist-packages (21.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask) (1.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from gevent) (54.2.0)
# Requirement already satisfied: zope.event in /usr/local/lib/python3.7/dist-packages (from gevent) (4.5.0)
# Requirement already satisfied: greenlet<2.0,>=0.4.17; platform_python_implementation == "CPython" in /usr/local/lib/python3.7/dist-packages (from gevent) (1.0.0)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.7/dist-packages (from gevent) (5.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.10.1->flask) (1.1.1)

# %%
procfile = 'web: gunicorn app:app'
procfiles= open("/content/Procfile","w")
procfiles.write(procfile)
procfiles.close()

# %%
# !pip install flask-ngrok
from flask_ngrok import run_with_ngrok
from flask import Flask
# Out:
# Requirement already satisfied: flask-ngrok in /usr/local/lib/python3.7/dist-packages (0.0.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (2.23.0)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (1.1.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2020.12.5)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: click>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.10.1->Flask>=0.8->flask-ngrok) (1.1.1)

# %%
a = '''
<!doctype html>
<html lang="en">
<head>
<title>My number recognizer</title>
</head> 
  <body>
 
          <h3>Image Recognition Server</h3>
       
      <form action="" method=post enctype=multipart/form-data>
        <input type=file name=file>
        <input type=submit value=Upload>
    </form>
    {{label}}  
     
  </body>
  </html>
  '''

# %%
# !mkdir '/content/templates'
# !mkdir '/content/uploads'

Html_file = open("/content/templates/index.html", "w")
Html_file.write(a)
Html_file.close()
# Out:
# mkdir: cannot create directory ‘/content/templates’: File exists
# mkdir: cannot create directory ‘/content/uploads’: File exists

# %%
import os
import cv2
import numpy as np
from flask import Flask, render_template, request
from keras.preprocessing import image
from keras.preprocessing.image import load_img, img_to_array

app = Flask(__name__)
run_with_ngrok(app)
app.config['UPLOADS'] = 'uploads'


def load_mymodel():
    global mymodel
    mymodel = keras.models.load_model('best_model.h5')

@app.route('/')
def home():
    return render_template('index.html')

def rgb2gray(rgb):
    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
    return gray

def predictions(file):
    """img = image.load_img(file, target_size=(28,28), color_mode="grayscale")
    img = img_to_array(img)"""
    img = cv2.imread(file)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (28,28))
    img = np.resize(img, (1, 28*28))
    """img = np.expand_dims(img, axis=0)"""
    ans = mymodel.predict_classes(img)
    return ans


@app.route('/', methods=['POST'])
def upload_files():
    file = request.files['file']
    filepath = os.path.join(app.config['UPLOADS'], file.filename)
    file.save(filepath)
    output = predictions(filepath)
    if output.astype('int32') == 0:
      output = '0'
    elif output.astype('int32') == 1:
      output = '1'
    elif output.astype('int32') == 2:
      output = '2'
    elif output.astype('int32') == 3:
      output = '3'
    elif output.astype('int32') == 4:
      output = '4'
    elif output.astype('int32') == 5:
      output = '5'
    elif output.astype('int32') == 6:
      output = '6'
    elif output.astype('int32') == 7:
      output = '7'
    elif output.astype('int32') == 8:
      output = '8'
    else:
      output = '9'

    return render_template('index.html', label=output)



if __name__=='__main__':
    load_mymodel()
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# Exception in thread Thread-12:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 1177, in run
#     self.function(*self.args, **self.kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/flask_ngrok.py", line 70, in start_ngrok
#     ngrok_address = _run_ngrok()
#   File "/usr/local/lib/python3.7/dist-packages/flask_ngrok.py", line 38, in _run_ngrok
#     tunnel_url = j['tunnels'][0]['public_url']  # Do the parsing of the get
# IndexError: list index out of range

# %% [markdown]
# ## Performance in real world

# %% [markdown]
# ### Testing Images
#
# ![mnist_0.jpg](data:image/jpeg;base64,...)    ![mnist_1.jpg](data:image/jpeg;base64,...)    ![mnist_2.jpg](data:image/jpeg;base64,...)    ![mnist_3.jpg](data:image/jpeg;base64,...)    ![mnist_4.jpg](data:image/jpeg;base64,...)    ![mnist_5.jpg](data:image/jpeg;base64,...)    ![mnist_6.jpg](data:image/jpeg;base64,...)     ![mnist_7.jpg](data:image/jpeg;base64,...)    ![mnist_8.jpg](data:image/jpeg;base64,...)    ![mnist_9.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Detection
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# and so on...

# %% [markdown]
# The images of digits were classified with proper results, random images were classifed to the nearest digit the model thought of, as we have only 10 outputs here and not a misclassified or not regognized one.
