# %% [markdown]
# <a href="https://colab.research.google.com/github/rajbhadalia/DL.01/blob/main/DL_Exp1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
 
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from keras.preprocessing.image import ImageDataGenerator

#dl libraraies
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.utils import to_categorical

# specifically for cnn
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
 
import tensorflow as tf
import random as rn

# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
import cv2                  
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

# %%
# !wget http://upscfever.com/datasets/flowers-new.zip -P drive/app
import os
os.chdir('/content/drive/app')  #change dir
# !unzip -q flowers-new.zip  #unzip data in test/
# Out:
# --2021-03-31 14:07:53--  http://upscfever.com/datasets/flowers-new.zip
# Resolving upscfever.com (upscfever.com)... 172.67.193.2, 104.21.90.10, 2606:4700:3033::6815:5a0a, ...
# Connecting to upscfever.com (upscfever.com)|172.67.193.2|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://upscfever.com/datasets/flowers-new.zip [following]
# --2021-03-31 14:07:53--  https://upscfever.com/datasets/flowers-new.zip
# Connecting to upscfever.com (upscfever.com)|172.67.193.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘drive/app/flowers-new.zip’
#
# flowers-new.zip         [           <=>      ]   5.74M  2.23MB/s    in 2.6s
#
# 2021-03-31 14:07:57 (2.23 MB/s) - ‘drive/app/flowers-new.zip’ saved [6021364]

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
X=[]
Z=[]
IMG_SIZE=150
FLOWER_DAISY_DIR='/content/drive/app/flowers/daisy'
FLOWER_SUNFLOWER_DIR='/content/drive/app/flowers/sunflower'
FLOWER_TULIP_DIR='/content/drive/app/flowers/tulip'
FLOWER_DANDI_DIR='/content/drive/app/flowers/dandelion'
FLOWER_ROSE_DIR='/content/drive/app/flowers/rose'

# %%
def assign_label(img,flower_type):
    return flower_type

# %%
def make_train_data(flower_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,flower_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
        
        X.append(np.array(img))
        Z.append(str(label))

# %%
make_train_data('Daisy',FLOWER_DAISY_DIR)
print(len(X))
# Out:
# 100%|██████████| 13/13 [00:00<00:00, 215.15it/s]
# 13

# %%
make_train_data('Sunflower',FLOWER_SUNFLOWER_DIR)
print(len(X))
# Out:
# 100%|██████████| 26/26 [00:00<00:00, 436.31it/s]
# 39

# %%
make_train_data('Tulip',FLOWER_TULIP_DIR)
print(len(X))
# Out:
# 100%|██████████| 26/26 [00:00<00:00, 423.40it/s]
# 65

# %%
make_train_data('Dandelion',FLOWER_DANDI_DIR)
print(len(X))
# Out:
# 100%|██████████| 26/26 [00:00<00:00, 404.07it/s]
# 91

# %%
make_train_data('Rose',FLOWER_ROSE_DIR)
print(len(X))
# Out:
# 100%|██████████| 26/26 [00:00<00:00, 403.71it/s]
# 117

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Flower: '+Z[l])
        
plt.tight_layout()

# %%
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,5)
X=np.array(X)
X=X/255

# %%
X.shape
# Out:
# (117, 150, 150, 3)

# %%
Y.shape
# Out:
# (117, 5)

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25)

# %%
y_test.shape
# Out:
# (30, 5)

# %%
# # modelling starts using a CNN.

model = Sequential()
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same',activation ='relu', input_shape = (150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
 

model.add(Conv2D(filters =96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Conv2D(filters = 96, kernel_size = (3,3),padding = 'Same',activation ='relu'))
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(5, activation = "softmax"))

# %%
#using a LR Annealer
batch_size=128
epochs=50

from keras.callbacks import ReduceLROnPlateau
red_lr= ReduceLROnPlateau(monitor='val_acc',patience=3,verbose=1,factor=0.1)

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %%
model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 32)      2432
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 96)        55392
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 96)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 96)        83040
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 96)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 7776)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3981824
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 2565
# =================================================================
# Total params: 4,143,749
# Trainable params: 4,143,749
# Non-trainable params: 0
# _________________________________________________________________

# %%
History = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test), 
                              verbose = 1)
# model.fit(x_train,y_train,epochs=epochs,batch_size=batch_size,validation_data = (x_test,y_test))
# Out:
# Epoch 1/50
# 1/1 [==============================] - 34s 34s/step - loss: 1.6037 - accuracy: 0.1954 - val_loss: 2.0756 - val_accuracy: 0.2000
# Epoch 2/50
# 1/1 [==============================] - 0s 468ms/step - loss: 1.8305 - accuracy: 0.2299 - val_loss: 1.6194 - val_accuracy: 0.3333
# Epoch 3/50
# 1/1 [==============================] - 0s 474ms/step - loss: 1.6077 - accuracy: 0.2414 - val_loss: 1.5704 - val_accuracy: 0.3333
# Epoch 4/50
# 1/1 [==============================] - 0s 457ms/step - loss: 1.5537 - accuracy: 0.4713 - val_loss: 1.5678 - val_accuracy: 0.1333
# Epoch 5/50
# 1/1 [==============================] - 0s 469ms/step - loss: 1.5167 - accuracy: 0.2759 - val_loss: 1.5477 - val_accuracy: 0.2333
# Epoch 6/50
# 1/1 [==============================] - 0s 478ms/step - loss: 1.4601 - accuracy: 0.3793 - val_loss: 1.4279 - val_accuracy: 0.4000
# Epoch 7/50
# 1/1 [==============================] - 0s 486ms/step - loss: 1.3820 - accuracy: 0.4023 - val_loss: 1.3518 - val_accuracy: 0.5333
# Epoch 8/50
# 1/1 [==============================] - 0s 498ms/step - loss: 1.2788 - accuracy: 0.4713 - val_loss: 1.2237 - val_accuracy: 0.6333
# Epoch 9/50
# 1/1 [==============================] - 0s 495ms/step - loss: 1.1673 - accuracy: 0.5402 - val_loss: 1.1352 - val_accuracy: 0.5333
# Epoch 10/50
# 1/1 [==============================] - 0s 497ms/step - loss: 1.0717 - accuracy: 0.5172 - val_loss: 1.0747 - val_accuracy: 0.5333
# Epoch 11/50
# 1/1 [==============================] - 0s 493ms/step - loss: 0.9672 - accuracy: 0.6092 - val_loss: 0.9027 - val_accuracy: 0.5667
# Epoch 12/50
# 1/1 [==============================] - 0s 481ms/step - loss: 0.9769 - accuracy: 0.5977 - val_loss: 2.1855 - val_accuracy: 0.3333
# Epoch 13/50
# 1/1 [==============================] - 1s 514ms/step - loss: 1.3667 - accuracy: 0.4483 - val_loss: 1.0432 - val_accuracy: 0.5667
# Epoch 14/50
# 1/1 [==============================] - 1s 501ms/step - loss: 0.9110 - accuracy: 0.6552 - val_loss: 0.9391 - val_accuracy: 0.5333
# Epoch 15/50
# 1/1 [==============================] - 0s 497ms/step - loss: 1.1285 - accuracy: 0.4943 - val_loss: 0.9286 - val_accuracy: 0.5333
# Epoch 16/50
# 1/1 [==============================] - 0s 487ms/step - loss: 0.9326 - accuracy: 0.6092 - val_loss: 1.1406 - val_accuracy: 0.5000
# Epoch 17/50
# 1/1 [==============================] - 1s 502ms/step - loss: 0.8232 - accuracy: 0.7471 - val_loss: 1.4911 - val_accuracy: 0.4667
# Epoch 18/50
# 1/1 [==============================] - 1s 516ms/step - loss: 0.9587 - accuracy: 0.6667 - val_loss: 1.4104 - val_accuracy: 0.4333
# Epoch 19/50
# 1/1 [==============================] - 0s 495ms/step - loss: 0.9729 - accuracy: 0.6092 - val_loss: 1.1224 - val_accuracy: 0.4333
# Epoch 20/50
# 1/1 [==============================] - 0s 489ms/step - loss: 0.8423 - accuracy: 0.6322 - val_loss: 1.0131 - val_accuracy: 0.5333
# Epoch 21/50
# 1/1 [==============================] - 0s 494ms/step - loss: 0.7749 - accuracy: 0.6897 - val_loss: 1.0940 - val_accuracy: 0.5667
# Epoch 22/50
# 1/1 [==============================] - 1s 510ms/step - loss: 0.8145 - accuracy: 0.7011 - val_loss: 1.1775 - val_accuracy: 0.5667
# Epoch 23/50
# 1/1 [==============================] - 1s 506ms/step - loss: 0.8240 - accuracy: 0.6782 - val_loss: 1.2685 - val_accuracy: 0.5000
# Epoch 24/50
# 1/1 [==============================] - 0s 486ms/step - loss: 0.7198 - accuracy: 0.7241 - val_loss: 1.4521 - val_accuracy: 0.4667
# Epoch 25/50
# 1/1 [==============================] - 0s 493ms/step - loss: 0.7107 - accuracy: 0.7701 - val_loss: 1.5151 - val_accuracy: 0.4667
# Epoch 26/50
# 1/1 [==============================] - 0s 489ms/step - loss: 0.7991 - accuracy: 0.6322 - val_loss: 1.3624 - val_accuracy: 0.4667
# Epoch 27/50
# 1/1 [==============================] - 0s 496ms/step - loss: 0.7115 - accuracy: 0.7471 - val_loss: 1.2737 - val_accuracy: 0.5000
# Epoch 28/50
# 1/1 [==============================] - 0s 482ms/step - loss: 0.5880 - accuracy: 0.8046 - val_loss: 1.3668 - val_accuracy: 0.5000
# Epoch 29/50
# 1/1 [==============================] - 1s 514ms/step - loss: 0.5853 - accuracy: 0.8161 - val_loss: 1.5255 - val_accuracy: 0.5333
# Epoch 30/50
# 1/1 [==============================] - 1s 501ms/step - loss: 0.6383 - accuracy: 0.6897 - val_loss: 1.4824 - val_accuracy: 0.5333
# Epoch 31/50
# 1/1 [==============================] - 0s 493ms/step - loss: 0.5838 - accuracy: 0.7356 - val_loss: 1.9768 - val_accuracy: 0.4333
# Epoch 32/50
# 1/1 [==============================] - 0s 492ms/step - loss: 0.5419 - accuracy: 0.8046 - val_loss: 1.9168 - val_accuracy: 0.4667
# Epoch 33/50
# 1/1 [==============================] - 1s 524ms/step - loss: 0.5473 - accuracy: 0.7701 - val_loss: 1.7256 - val_accuracy: 0.4333
# Epoch 34/50
# 1/1 [==============================] - 1s 518ms/step - loss: 0.5213 - accuracy: 0.8161 - val_loss: 1.7021 - val_accuracy: 0.4333
# Epoch 35/50
# 1/1 [==============================] - 1s 505ms/step - loss: 0.4875 - accuracy: 0.8276 - val_loss: 1.9945 - val_accuracy: 0.4000
# Epoch 36/50
# 1/1 [==============================] - 0s 496ms/step - loss: 0.4702 - accuracy: 0.8161 - val_loss: 2.0099 - val_accuracy: 0.4667
# Epoch 37/50
# 1/1 [==============================] - 0s 489ms/step - loss: 0.4161 - accuracy: 0.8736 - val_loss: 2.0774 - val_accuracy: 0.5667
# Epoch 38/50
# 1/1 [==============================] - 0s 494ms/step - loss: 0.3911 - accuracy: 0.8506 - val_loss: 2.2010 - val_accuracy: 0.5667
# Epoch 39/50
# 1/1 [==============================] - 0s 488ms/step - loss: 0.4111 - accuracy: 0.8391 - val_loss: 2.8131 - val_accuracy: 0.5000
# Epoch 40/50
# 1/1 [==============================] - 1s 526ms/step - loss: 0.4092 - accuracy: 0.8506 - val_loss: 2.2404 - val_accuracy: 0.4667
# Epoch 41/50
# 1/1 [==============================] - 1s 501ms/step - loss: 0.3437 - accuracy: 0.8851 - val_loss: 1.8913 - val_accuracy: 0.5667
# Epoch 42/50
# 1/1 [==============================] - 0s 499ms/step - loss: 0.4693 - accuracy: 0.8161 - val_loss: 2.2430 - val_accuracy: 0.5333
# Epoch 43/50
# 1/1 [==============================] - 0s 488ms/step - loss: 0.3975 - accuracy: 0.8391 - val_loss: 2.4467 - val_accuracy: 0.5000
# Epoch 44/50
# 1/1 [==============================] - 1s 508ms/step - loss: 0.2619 - accuracy: 0.9195 - val_loss: 2.5725 - val_accuracy: 0.4667
# Epoch 45/50
# 1/1 [==============================] - 0s 493ms/step - loss: 0.4158 - accuracy: 0.8391 - val_loss: 2.5404 - val_accuracy: 0.5000
# Epoch 46/50
# 1/1 [==============================] - 0s 481ms/step - loss: 0.3692 - accuracy: 0.8506 - val_loss: 2.3833 - val_accuracy: 0.5333
# Epoch 47/50
# 1/1 [==============================] - 0s 488ms/step - loss: 0.3937 - accuracy: 0.8621 - val_loss: 2.1170 - val_accuracy: 0.4667
# Epoch 48/50
# 1/1 [==============================] - 0s 482ms/step - loss: 0.3233 - accuracy: 0.8736 - val_loss: 2.0607 - val_accuracy: 0.4667
# Epoch 49/50
# 1/1 [==============================] - 1s 508ms/step - loss: 0.2863 - accuracy: 0.8851 - val_loss: 2.3049 - val_accuracy: 0.4667
# Epoch 50/50
# 1/1 [==============================] - 0s 495ms/step - loss: 0.2707 - accuracy: 0.8851 - val_loss: 2.6030 - val_accuracy: 0.4667

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(History.history['accuracy'])
plt.plot(History.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
predictions = model.predict(x_test)
predictions = np.argmax(predictions,axis = 1)

# %%
y_test_ = to_categorical(y_test)

# %%
predictions = to_categorical(predictions,5)

# %%
a = np.argmax(predictions, axis=1 )

# %%
b = np.argmax(y_test ,axis=1)

# %%
cm = confusion_matrix(a,b)
cm
# Out:
# array([[1, 2, 0, 2, 1],
#        [0, 1, 0, 0, 0],
#        [1, 3, 4, 1, 2],
#        [0, 1, 0, 5, 0],
#        [2, 1, 0, 0, 3]])

# %%
accuracy = sum(cm[i][i] for i in range(5)) / y_test.shape[0]
print("accuracy = " + str(accuracy))
# Out:
# accuracy = 0.4666666666666667

# %% [markdown]
# Screenshot of accuracy

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.metrics import precision_score, recall_score
print('precision score - ',precision_score(y_test, predictions, average="macro"))
print('recall score - ', recall_score(y_test, predictions, average="macro"))
# Out:
# precision score -  0.5727272727272728
# recall score -  0.5

# %%
model.save('final_flowers_model2')
# Out:
# INFO:tensorflow:Assets written to: final_flowers_model2/assets

# %%
from tensorflow import keras
model = keras.models.load_model('final_flowers_model2')
